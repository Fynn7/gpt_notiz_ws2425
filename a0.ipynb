# %% [markdown]
# # Herzlich Willkommen!
# # Welcome!

# %% [markdown]
# ————————————————————————————————————————

# %% [markdown]
# **G06|Di.|14:00-16:00 s.t.|LC140**
#
# **G08|Mi.|16:00-18:00 s.t.|LC036**

# %% [markdown]
# ### English? No Problem!
#
# ### Fragen & Vorschläge ❤

# %% [markdown]
# ————————————————————————————————————————

# %% [markdown]
# # Python 3 Installation
#
# - offizielle Website: <a href="https://www.python.org/downloads">python.org/downloads</a>
# - MS Store (für Windows OS)

# %% [markdown]
# ————————————————————————————————————————

# %% [markdown]
# # `print()`

# %%
print("Hello Alice")

# %%
import sys

name = sys.argv[1]
print("Hello", name)

# %%
name = input("What is your name? ")
print("Hello", name)

# %% [markdown]
# # Quiz

# %%
exp1 = True+True
exp2 = True*False
exp3 = -False

# %% [markdown]
# A. True
# B. False
# C. 0
# D. 1
# E. 2

# %%
exp1, exp2, exp3

# %% [markdown]
# ————————————————————————————————————————

# %% [markdown]
# # Wiederholung

# %% [markdown]
# ```python
# str

# %%
"a"+"b"+"c"

# %%
"Come on " * 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"="*1000

# %% [markdown]
# ```python
# int

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```python
# bool

# %%
6/7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
